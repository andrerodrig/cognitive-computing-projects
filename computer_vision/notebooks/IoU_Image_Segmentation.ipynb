# %%
import cv2
import numpy
import matplotlib.pyplot as plt
img = cv2.imread('/content/002.jpg')

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
# An example of first bounding box
img_true = cv2.imread('/content/002_mask.png')
result1 = cv2.bitwise_and(img, img_true)
result1 = cv2.cvtColor(result1, cv2.COLOR_BGR2RGB)
plt.imshow(result1)

# %%
# An example of second bounding box
img_find = cv2.imread('/content/002_teste___IOU.png')
result2 = cv2.bitwise_and(img, img_find)
result2 = cv2.cvtColor(result2, cv2.COLOR_BGR2RGB)
plt.imshow(result2)

# %%
# IoU calculation
intersection = numpy.logical_and(result1, result2)
union = numpy.logical_or(result1, result2)
iou_score = numpy.sum(intersection) / numpy.sum(union)
print('IoU is %s' % iou_score)
# Out:
# IoU is 0.3191457687025174

# %%
import cv2
import numpy as np

def IoU_image_seg(img_gray, ground_truth, img_seg):
  """
            Funcao responsavel pela métrica IoU
            Arguments:
              img_gray: np.array -- Uma matriz NumPy que representa a imagem na escala de cinza
                com a forma (num_rows, num_cols, num_channels)
              ground_truth: np.array -- Uma matriz NumPy que representa a imagem na escala de cinza
                com a forma (num_rows, num_cols, num_channels)
              img_seg:  np.array -- Uma matriz NumPy que representa a imagem binarizada
            Return:
              
  """
  result1 = cv2.bitwise_and(img_gray, ground_truth)
  result1 = cv2.cvtColor(result1, cv2.COLOR_BGR2RGB)

  result2 = cv2.bitwise_and(img_gray, img_seg)
  result2 = cv2.cvtColor(result2, cv2.COLOR_BGR2RGB)

  intersection = np.logical_and(result1, result2)
  union = np.logical_or(result1, result2)
  iou_score = np.sum(intersection) / np.sum(union)
  print('IoU is %s' % iou_score)

# %%
def main():
  img = cv2.imread('/content/002.jpg')
  ground_truth = cv2.imread('/content/002_mask.png')
  img_seg = cv2.imread('/content/002_teste2___IOU.png')

  # Testando a funcao
  IoU_image_seg(img, ground_truth, img_seg)

if __name__ == "__main__":
  main()

# %% [markdown]
# # teste

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/content/002.jpg")
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
tipo = cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU
limiar, image_binary = cv2.threshold(image_gray , 0, 255, tipo)
plt.imshow(image_binary,cmap="gray")

# %%
img = cv2.imread('/content/002.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ground_truth = cv2.imread('/content/002_mask.png')
ground_truth_gray = cv2.cvtColor(ground_truth, cv2.COLOR_BGR2GRAY)
# limiar, image_binary = cv2.threshold(ground_truth_gray, 0, 255, tipo)


IoU_image_seg(img_gray, ground_truth_gray, image_binary)
# plt.imshow(img, cmap="gray")
# Out:
# IoU is 0.9763441329089085
