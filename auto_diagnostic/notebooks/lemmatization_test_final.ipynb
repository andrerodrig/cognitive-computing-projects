# %%
from nltk import RegexpTokenizer

from auto_diagnostic.lemmatization import Lemmatization
from auto_diagnostic.preprocess import tokenize
from dataloader.makedata import Dataloader

# %%
# text = ['As frases de tópico são semelhantes às declarações de mini tese.\
#         Como uma declaração de tese, um tópico frasal tem um \
#         ponto principal. Considerando que a tese é o ponto principal do ensaio',\
#         'o tópico frasal é o ponto principal do parágrafo.\
#         Como a declaração de tese, um tópico frasal tem uma função unificadora. \
#         Mas uma declaração de tese ou frase de tópico por si só map(lambda x: tokenizer.tokenize(x), text)não garante unidade.', \
#         'Um ensaio é unificado se todos os parágrafos se relacionam com a tese,\
#         um parágrafo é unificado se todas as sentenças se relacionam com o tópico frasal while.']

# %%
data = Dataloader()
df = data.make_csv()
# Out:
# /home/aizen/dev/atlantico-academy/cognitive-comp/auto-diagnostic/dataloader/makedata.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[text_field][i]=unidecode.unidecode(df[text_field].iloc[i])
#
# /home/aizen/dev/atlantico-academy/cognitive-comp/auto-diagnostic/dataloader/makedata.py:33: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[text_field] = df[text_field].str.replace(r"[()\;\,\%\-\/\--\.!?@\'\`\"\_\n]", " ")

# %%
df
# Out:
#    txt_idx                                        text_column
# 0        0  nao ha dados exatos a respeito do numero de pr...
# 1        1  embora haja relativamente poucos dados no bras...
# 2        2  o cancer de pulmao e a doenca maligna mais com...

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
tokenized_text = tokenize(df['text_column'])

# %%
tokenized_text
# Out:
# [['nao',
#   'ha',
#   'dados',
#   'exatos',
#   'a',
#   'respeito',
#   'do',
#   'numero',
#   'de',
#   'procedimentos',
#   'cirurgicos',
#   'realizados',
#   'para',
#   'tratar',
#   'pacientes',
#   'com',
#   'cancer',
#   'de',
#   'pulmao',
#   'de',
#   'acordo',
#   'com',
#   'o',
#   'departamento',
#   'de',
#   'informatica',
#   'do',
#   'sus',
#   'um',
#   'banco',
#   'de',
#   'dados',
#   'do',
#   'sistema',
#   'publico',
#   'de',
#   'saude',
#   'que',
#   'cobre',
#   'aproximadamente',
#   '75',
#   'da',
#   'populacao',
#   'brasileira',
#   'uma',
#   'mediana',
#   'de',
#   '964',
#   'lobectomias',
#   'e',
#   'segmentectomias',
#   'pulmonares',
#   'foram',
#   'realizadas',
#   'anualmente',
#   'entre',
#   '2007',
#   'e',
#   '2014',
#   '52',
#   'no',
#   'entanto',
#   'ha',
#   'a',
#   'possibilidade',
#   'de',
#   'que',
#   'esse',
#   'numero',
#   'nao',
#   'seja',
#   'exato',
#   'e',
#   'possivel',
#   'que',
#   'lobectomias',
#   'e',
#   'segmentectomias',
#   'tenham',
#   'sido',
#   'realizadas',
#   'para',
#   'tratar',
#   'doencas',
#   'que',
#   'nao',
#   'o',
#   'cancer',
#   'de',
#   'pulmao',
#   'o',
#   'banco',
#   'de',
#   'dados',
#   'e',
#   'restrito',
#   'ao',
#   'sistema',
#   'publico',
#   'de',
#   'saude',
#   'e',
#   'a',
#   'qualidade',
#   'dos',
#   'dados',
#   'e',
#   'questionavel',
#   'apenas',
#   'uma',
#   'pequena',
#   'proporcao',
#   'de',
#   'pacientes',
#   'e',
#   'submetida',
#   'a',
#   'cirurgia',
#   'com',
#   'intencao',
#   'curativa',
#   'os',
#   'dados',
#   'sugerem',
#   'que',
#   'aproximadamente',
#   '25',
#   'dos',
#   'pacientes',
#   'sao',
#   'submetidos',
#   'a',
#   'tratamento',
#   'cirurgico',
#   '19',
#   '22',
#   '23',
#   'o',
#   'acesso',
#   'a',
#   'cirurgia',
#   'curativa',
#   'e',
#   'provavelmente',
#   'influenciado',
#   'por',
#   'diferencas',
#   'socioeconomicas',
#   'performance',
#   'status',
#   'comorbidades',
#   'idade',
#   'avancada',
#   'e',
#   'distribuicao',
#   'geografica',
#   '22',
#   'segundo',
#   'a',
#   'secretaria',
#   'de',
#   'saude',
#   'do',
#   'estado',
#   'de',
#   'sao',
#   'paulo',
#   'a',
#   'probabilidade',
#   'de',
#   'realizacao',
#   'de',
#   'cirurgia',
#   'e',
#   'menor',
#   'em',
#   'pacientes',
#   'com',
#   'menor',
#   'escolaridade',
#   'atualmente',
#   'existem',
#   '763',
#   'cirurgioes',
#   'toracicos',
#   'no',
#   'brasil',
#   'concentrados',
#   'nas',
#   'regioes',
#   'sul',
#   'e',
#   'sudeste',
#   'do',
#   'pais',
#   '53',
#   'em',
#   'uma',
#   'pesquisa',
#   'promovida',
#   'pela',
#   'sociedade',
#   'brasileira',
#   'de',
#   'cirurgia',
#   'toracica',
#   '51',
#   'dos',
#   'participantes',
#   'disseram',
#   'que',
#   'trabalhavam',
#   'em',
#   'cidades',
#   'com',
#   'mais',
#   'de',
#   'um',
#   'milhao',
#   'de',
#   'habitantes',
#   '54',
#   'portanto',
#   'mesmo',
#   'que',
#   'o',
#   'numero',
#   'absoluto',
#   'de',
#   'cirurgioes',
#   'toracicos',
#   'seja',
#   'adequado',
#   'sua',
#   'distribuicao',
#   'e',
#   'motivo',
#   'de',
#   'preocupacao',
#   'cidades',
#   'de',
#   'tamanho',
#   'medio',
#   'e',
#   'regioes',
#   'densamente',
#   'povoadas',
#   'no',
#   'centro',
#   'norte',
#   'e',
#   'nordeste',
#   'do',
#   'brasil',
#   'estao',
#   'mal',
#   'servidas',
#   'no',
#   'tocante',
#   'a',
#   'cirurgia',
#   'toracica',
#   'a',
#   'cirurgia',
#   'toracica',
#   'videoassistida',
#   'esta',
#   'crescendo',
#   'rapidamente',
#   'no',
#   'pais',
#   'as',
#   'taxas',
#   'de',
#   'mortalidade',
#   'em',
#   '30',
#   'dias',
#   'nas',
#   'duas',
#   'maiores',
#   'series',
#   'de',
#   'casos',
#   'cirurgicos',
#   'relatados',
#   'que',
#   'incluiram',
#   'pacientes',
#   'submetidos',
#   'a',
#   'lobectomia',
#   'em',
#   'virtude',
#   'de',
#   'cancer',
#   'de',
#   'pulmao',
#   'foram',
#   'de',
#   '2',
#   '9',
#   'e',
#   '4',
#   '3',
#   '55',
#   '56',
#   'grandes',
#   'series',
#   'de',
#   'casos',
#   'internacionais',
#   'publicadas',
#   'nos',
#   'anos',
#   '2000',
#   'revelaram',
#   'uma',
#   'taxa',
#   'de',
#   'mortalidade',
#   'um',
#   'pouco',
#   'menor',
#   'de',
#   'aproximadamente',
#   '1',
#   '57',
#   'esses',
#   'numeros',
#   'sugerem',
#   'que',
#   'e',
#   'possivel',
#   'melhorar',
#   'a',
#   'cirurgia',
#   'de',
#   'cancer',
#   'de',
#   'pulmao',
#   'no',
#   'brasil',
#   'espera',
#   'se',
#   'que',
#   'a',
#   'disseminacao',
#   'e',
#   'disponibilidade',
#   'de',
#   'novas',
#   'tecnicas',
#   'tais',
#   'como',
#   'a',
#   'cirurgia',
#   'videoassistida',
#   'e',
#   'a',
#   'cirurgia',
#   'robotica',
#   'acelerem',
#   'esse',
#   'processo'],
#  ['embora',
#   'haja',
#   'relativamente',
#   'poucos',
#   'dados',
#   'no',
#   'brasil',
#   'a',
#   'respeito',
#   'de',
#   'como',
#   'o',
#   'cancer',
#   'de',
#   'pulmao',
#   'e',
#   'diagnosticado',
#   'e',
#   'classificado',
#   'foram',
#   'publicados',
#   'alguns',
#   'dados',
#   'nos',
#   'ultimos',
#   '15',
#   'anos',
#   'assim',
#   'como',
#   'ocorre',
#   'em',
#   'paises',
#   'desenvolvidos',
#   'o',
#   'cancer',
#   'pulmonar',
#   'de',
#   'celulas',
#   'nao',
#   'pequenas',
#   'cpcnp',
#   'no',
#   'brasil',
#   'e',
#   'geralmente',
#   'diagnosticado',
#   'em',
#   'estagios',
#   'avancados',
#   'e',
#   'apresenta',
#   'baixas',
#   'taxas',
#   'de',
#   'sobrevida',
#   'no',
#   'geral',
#   'aproximadamente',
#   '70',
#   'dos',
#   'pacientes',
#   'apresentam',
#   'doenca',
#   'localmente',
#   'avancada',
#   'ou',
#   'metastatica',
#   'estagio',
#   'iii',
#   'e',
#   'iv',
#   'respectivamente',
#   'de',
#   'acordo',
#   'com',
#   'um',
#   'grande',
#   'banco',
#   'de',
#   'dados',
#   'de',
#   'casos',
#   'de',
#   'cancer',
#   'no',
#   'estado',
#   'de',
#   'sao',
#   'paulo',
#   'apenas',
#   '8',
#   '8',
#   'dos',
#   '20',
#   '850',
#   'pacientes',
#   'com',
#   'cancer',
#   'de',
#   'pulmao',
#   'registrados',
#   'no',
#   'sistema',
#   'entre',
#   '2000',
#   'e',
#   '2010',
#   'apresentavam',
#   'doenca',
#   'no',
#   'estagio',
#   'i',
#   '14',
#   'essas',
#   'porcentagens',
#   'contrastam',
#   'com',
#   'as',
#   'de',
#   '15',
#   '4',
#   'e',
#   '14',
#   '5',
#   'referentes',
#   'a',
#   'um',
#   'periodo',
#   'semelhante',
#   'nos',
#   'eua',
#   'e',
#   'no',
#   'reino',
#   'unido',
#   'respectivamente',
#   '15',
#   '16',
#   'um',
#   'ensaio',
#   'brasileiro',
#   'de',
#   'rastreamento',
#   'de',
#   'cancer',
#   'de',
#   'pulmao',
#   'foi',
#   'realizado',
#   'a',
#   'fim',
#   'de',
#   'determinar',
#   'a',
#   'eficacia',
#   'do',
#   'rastreamento',
#   'no',
#   'pais',
#   '17',
#   'entre',
#   'janeiro',
#   'de',
#   '2013',
#   'e',
#   'julho',
#   'de',
#   '2014',
#   '790',
#   'voluntarios',
#   'se',
#   'ofereceram',
#   'para',
#   'participar',
#   'do',
#   'estudo',
#   'cujos',
#   'criterios',
#   'de',
#   'elegibilidade',
#   'foram',
#   'os',
#   'mesmos',
#   'que',
#   'os',
#   'aplicados',
#   'em',
#   'um',
#   'ensaio',
#   'nacional',
#   'de',
#   'rastreamento',
#   'pulmonar',
#   'realizado',
#   'nos',
#   'eua',
#   'do',
#   'total',
#   'de',
#   'participantes',
#   '10',
#   'receberam',
#   'o',
#   'diagnostico',
#   'de',
#   'cpcnp',
#   'prevalencia',
#   'de',
#   '1',
#   '3',
#   'a',
#   'maioria',
#   'dos',
#   'quais',
#   'foi',
#   'classificada',
#   'em',
#   'estagio',
#   'i',
#   '17',
#   'foram',
#   'publicadas',
#   'varias',
#   'series',
#   'retrospectivas',
#   'nas',
#   'quais',
#   'foram',
#   'relatados',
#   'dados',
#   'provenientes',
#   'de',
#   'uma',
#   'unica',
#   'instituicao',
#   'a',
#   'respeito',
#   'da',
#   'histologia',
#   'estadiamento',
#   'e',
#   'desfechos',
#   'do',
#   'cancer',
#   'de',
#   'pulmao',
#   '18',
#   '26',
#   'curiosamente',
#   'a',
#   'presenca',
#   'de',
#   'celulas',
#   'escamosas',
#   'no',
#   'exame',
#   'histologico',
#   'parece',
#   'ser',
#   'mais',
#   'prevalente',
#   'em',
#   'servicos',
#   'publicos',
#   'de',
#   'saude',
#   'ao',
#   'passo',
#   'que',
#   'o',
#   'adenocarcinoma',
#   'predomina',
#   'em',
#   'instituicoes',
#   'privadas',
#   'nos',
#   'eua',
#   'as',
#   'taxas',
#   'de',
#   'carcinoma',
#   'de',
#   'celulas',
#   'escamosas',
#   'e',
#   'carcinoma',
#   'de',
#   'pequenas',
#   'celulas',
#   'do',
#   'pulmao',
#   'cpcp',
#   'diminuiram',
#   'apos',
#   'a',
#   'decada',
#   'de',
#   '1990',
#   'e',
#   'as',
#   'taxas',
#   'de',
#   'adenocarcinoma',
#   'aumentaram',
#   'no',
#   'periodo',
#   'entre',
#   '2006',
#   'e',
#   '2010',
#   'em',
#   'todas',
#   'as',
#   'racas',
#   'etnias',
#   'sexos',
#   '27',
#   'um',
#   'importante',
#   'centro',
#   'oncologico',
#   'no',
#   'estado',
#   'de',
#   'sao',
#   'paulo',
#   'analisou',
#   'dados',
#   'coletados',
#   'entre',
#   '1997',
#   'e',
#   '2008',
#   'referentes',
#   'a',
#   '1',
#   '887',
#   'pacientes',
#   'com',
#   'cancer',
#   'de',
#   'pulmao',
#   '18',
#   'houve',
#   'uma',
#   'queda',
#   'da',
#   'proporcao',
#   'de',
#   'cpcp',
#   'em',
#   'dois',
#   'periodo',
#   'diferentes',
#   '1997',
#   '2002',
#   'e',
#   '2003',
#   '2008',
#   'embora',
#   'nao',
#   'tenham',
#   'ocorrido',
#   'alteracoes',
#   'significativas',
#   'nos',
#   'subgrupos',
#   'histologicos',
#   'de',
#   'cpcnp',
#   '18',
#   'no',
#   'entanto',
#   'em',
#   'um',
#   'estudo',
#   'epidemiologico',
#   'no',
#   'qual',
#   'foram',
#   'avaliados',
#   'dados',
#   'de',
#   'casos',
#   'de',
#   '35',
#   '018',
#   'pacientes',
#   'com',
#   'diagnostico',
#   'de',
#   'cpcnp',
#   'nos',
#   'estados',
#   'do',
#   'rio',
#   'de',
#   'janeiro',
#   'e',
#   'sao',
#   'paulo',
#   'entre',
#   '2000',
#   'e',
#   '2011',
#   'observou',
#   'se',
#   'uma',
#   'tendencia',
#   'a',
#   'maior',
#   'prevalencia',
#   'de',
#   'adenocarcinoma',
#   'que',
#   'de',
#   'carcinoma',
#   'de',
#   'celulas',
#   'escamosas',
#   'no',
#   'exame',
#   'histologico',
#   'nos',
#   'ultimos',
#   'anos',
#   '43',
#   '3',
#   'vs',
#   '36',
#   '5'],
#  ['o',
#   'cancer',
#   'de',
#   'pulmao',
#   'e',
#   'a',
#   'doenca',
#   'maligna',
#   'mais',
#   'comum',
#   'em',
#   'todo',
#   'o',
#   'mundo',
#   'de',
#   'todos',
#   'os',
#   'novos',
#   'casos',
#   'de',
#   'cancer',
#   '13',
#   'sao',
#   'de',
#   'cancer',
#   'de',
#   'pulmao',
#   '1',
#   'de',
#   'acordo',
#   'com',
#   'o',
#   'global',
#   'burden',
#   'of',
#   'disease',
#   'study',
#   '2015',
#   'o',
#   'cancer',
#   'de',
#   'pulmao',
#   'e',
#   'tambem',
#   'a',
#   'principal',
#   'causa',
#   'de',
#   'mortalidade',
#   'por',
#   'cancer',
#   'mais',
#   'de',
#   '1',
#   '7',
#   '1',
#   '8',
#   'milhoes',
#   'de',
#   'mortes',
#   'por',
#   'ano',
#   'e',
#   'de',
#   'todos',
#   'os',
#   'tipos',
#   'de',
#   'cancer',
#   'o',
#   'que',
#   'apresenta',
#   'a',
#   'maior',
#   'taxa',
#   'de',
#   'mortalidade',
#   'padronizada',
#   'pela',
#   'idade',
#   '26',
#   '6',
#   'mortes',
#   'por',
#   '100',
#   '000',
#   'habitantes',
#   '2',
#   'no',
#   'brasil',
#   'o',
#   'instituto',
#   'nacional',
#   'de',
#   'cancer',
#   'inca',
#   'estimou',
#   'em',
#   '596',
#   '000',
#   'o',
#   'numero',
#   'de',
#   'novos',
#   'casos',
#   'de',
#   'cancer',
#   'em',
#   '2016',
#   '28',
#   '220',
#   '4',
#   '7',
#   'dos',
#   'quais',
#   'foram',
#   'casos',
#   'de',
#   'neoplasia',
#   'maligna',
#   'primaria',
#   'de',
#   'pulmao',
#   '3',
#   'o',
#   'cancer',
#   'de',
#   'pulmao',
#   'e',
#   'o',
#   'segundo',
#   'tipo',
#   'de',
#   'cancer',
#   'de',
#   'maior',
#   'incidencia',
#   'em',
#   'homens',
#   'e',
#   'o',
#   'quarto',
#   'tipo',
#   'de',
#   'cancer',
#   'de',
#   'maior',
#   'incidencia',
#   'em',
#   'mulheres',
#   'no',
#   'pais',
#   'figura',
#   '1',
#   '3',
#   'como',
#   'na',
#   'maioria',
#   'dos',
#   'paises',
#   'o',
#   'cancer',
#   'de',
#   'pulmao',
#   'e',
#   'a',
#   'principal',
#   'causa',
#   'de',
#   'mortalidade',
#   'por',
#   'cancer',
#   'no',
#   'brasil',
#   'a',
#   'taxa',
#   'de',
#   'sobrevida',
#   'em',
#   '5',
#   'anos',
#   'padronizada',
#   'pela',
#   'idade',
#   'no',
#   'pais',
#   'e',
#   'de',
#   '18',
#   'semelhante',
#   'as',
#   'taxas',
#   'globais',
#   'que',
#   'variam',
#   'de',
#   '10',
#   'a',
#   '20',
#   '4',
#   'em',
#   '2012',
#   'as',
#   'taxas',
#   'de',
#   'mortalidade',
#   'por',
#   'cancer',
#   'de',
#   'pulmao',
#   'padronizadas',
#   'pela',
#   'idade',
#   'foram',
#   'de',
#   '16',
#   '5',
#   'mortes',
#   '100',
#   '000',
#   'habitantes',
#   'e',
#   '8',
#   '6',
#   'mortes',
#   '100',
#   '000',
#   'habitantes',
#   'em',
#   'homens',
#   'e',
#   'mulheres',
#   'respectivamente',
#   '5',
#   'no',
#   'brasil',
#   'de',
#   '1979',
#   'a',
#   '2004',
#   'a',
#   'mortalidade',
#   'aumentou',
#   'de',
#   '10',
#   '6',
#   'mortes',
#   '100',
#   '000',
#   'habitantes',
#   'para',
#   '31',
#   '1',
#   'mortes',
#   '100',
#   '000',
#   'habitantes',
#   'em',
#   'homens',
#   'e',
#   'de',
#   '3',
#   '0',
#   'mortes',
#   '100',
#   '000',
#   'habitantes',
#   'para',
#   '5',
#   '4',
#   'mortes',
#   '100',
#   '000',
#   'habitantes',
#   'em',
#   'mulheres',
#   '6',
#   'as',
#   'taxas',
#   'de',
#   'mortalidade',
#   'tanto',
#   'as',
#   'brutas',
#   'como',
#   'as',
#   'ajustadas',
#   'pela',
#   'idade',
#   'em',
#   'homens',
#   'e',
#   'mulheres',
#   'diferiram',
#   'em',
#   'magnitude',
#   'em',
#   'todos',
#   'os',
#   'periodos',
#   '1980',
#   '2007',
#   'com',
#   'um',
#   'aumento',
#   'relativo',
#   'mais',
#   'significativo',
#   'nas',
#   'mulheres',
#   'que',
#   'nos',
#   'homens',
#   '78',
#   '4',
#   'vs',
#   '8',
#   '2',
#   'provavelmente',
#   'em',
#   'virtude',
#   'de',
#   'diferencas',
#   'na',
#   'prevalencia',
#   'do',
#   'tabagismo',
#   'figura',
#   '2',
#   'alem',
#   'disso',
#   'as',
#   'taxas',
#   'de',
#   'mortalidade',
#   'por',
#   'idade',
#   'aumentaram',
#   'em',
#   'homens',
#   'com',
#   'idade',
#   'igual',
#   'ou',
#   'superior',
#   'a',
#   '65',
#   'anos',
#   'e',
#   'em',
#   'mulheres',
#   'de',
#   'todas',
#   'as',
#   'idades',
#   '7',
#   'o',
#   'sistema',
#   'de',
#   'saude',
#   'brasileiro',
#   'e',
#   'dividido',
#   'em',
#   'cobertura',
#   'privada',
#   'e',
#   'cobertura',
#   'publica',
#   '27',
#   'e',
#   '73',
#   'respectivamente',
#   'como',
#   'sera',
#   'discutido',
#   'mais',
#   'adiante',
#   'na',
#   'presente',
#   'analise',
#   'e',
#   'evidente',
#   'que',
#   'ha',
#   'discrepancia',
#   'significativa',
#   'entre',
#   'o',
#   'sistema',
#   'publico',
#   'e',
#   'o',
#   'privado',
#   'no',
#   'tocante',
#   'a',
#   'disponibilidade',
#   'de',
#   'recursos',
#   'de',
#   'saude',
#   'e',
#   'aos',
#   'desfechos',
#   'dos',
#   'paciente',
#   'as',
#   'tendencias',
#   'da',
#   'mortalidade',
#   'por',
#   'cancer',
#   'de',
#   'pulmao',
#   'no',
#   'brasil',
#   'refletem',
#   'o',
#   'modelo',
#   'epidemiologico',
#   'da',
#   'mortalidade',
#   'relacionada',
#   'com',
#   'o',
#   'tabaco',
#   'o',
#   'uso',
#   'do',
#   'tabaco',
#   'aumentou',
#   'durante',
#   'as',
#   'decadas',
#   'de',
#   '1950',
#   'e',
#   '1960',
#   'e',
#   'atingiu',
#   'o',
#   'ponto',
#   'maximo',
#   'na',
#   'decada',
#   'de',
#   '1970',
#   'fortes',
#   'politicas',
#   'de',
#   'saude',
#   'publica',
#   'no',
#   'brasil',
#   'resultaram',
#   'em',
#   'reducao',
#   'do',
#   'consumo',
#   'de',
#   'tabaco',
#   'o',
#   'que',
#   'pode',
#   'servir',
#   'de',
#   'exemplo',
#   'para',
#   'outros',
#   'paises',
#   'de',
#   'baixa',
#   'e',
#   'media',
#   'renda',
#   'estudos',
#   'conduzidos',
#   'no',
#   'brasil',
#   'indicam',
#   'que',
#   'tanto',
#   'a',
#   'prevalencia',
#   'do',
#   'tabagismo',
#   'como',
#   'as',
#   'mortes',
#   'com',
#   'ele',
#   'relacionadas',
#   'diminuiram',
#   'aproximadamente',
#   '50',
#   '9',
#   'os',
#   'dados',
#   'provenientes',
#   'de',
#   'um',
#   'estudo',
#   'nacional',
#   'de',
#   'vigilancia',
#   'por',
#   'telefone',
#   'sobre',
#   'fatores',
#   'de',
#   'risco',
#   'de',
#   'doencas',
#   'cronicas',
#   'e',
#   'fatores',
#   'de',
#   'protecao',
#   'contra',
#   'essas',
#   'doencas',
#   'mostraram',
#   'que',
#   '12',
#   '7',
#   'dos',
#   'homens',
#   'e',
#   '8',
#   '0',
#   'das',
#   'mulheres',
#   'com',
#   '18',
#   'anos',
#   'de',
#   'idade',
#   'ou',
#   'mais',
#   'eram',
#   'fumantes',
#   'em',
#   '2016',
#   '10',
#   'em',
#   '1989',
#   'as',
#   'porcentagens',
#   'eram',
#   'de',
#   '43',
#   '3',
#   'e',
#   '27',
#   '0',
#   'respectivamente',
#   'os',
#   'principais',
#   'componentes',
#   'das',
#   'politicas',
#   'brasileiras',
#   'antitabaco',
#   'sao',
#   'a',
#   'proibicao',
#   'do',
#   'tabagismo',
#   'em',
#   'locais',
#   'publicos',
#   'impostos',
#   'mais',
#   'altos',
#   'sobre',
#   'produtos',
#   'do',
#   'tabaco',
#   'e',
#   'alertas',
#   'de',
#   'saude',
#   'nos',
#   'rotulos',
#   'das',
#   'embalagens',
#   'de',
#   'cigarros',
#   'apesar',
#   'dessa',
#   'diminuicao',
#   'do',
#   'consumo',
#   'de',
#   'tabaco',
#   'pesquisas',
#   'nacionais',
#   'com',
#   'criancas',
#   'no',
#   'brasil',
#   'ainda',
#   'mostram',
#   'uma',
#   'prevalencia',
#   'significativa',
#   'de',
#   'fumantes',
#   'na',
#   'populacao',
#   'jovem',
#   'em',
#   'diversas',
#   'cidades',
#   'alem',
#   'disso',
#   'as',
#   'doencas',
#   'relacionadas',
#   'com',
#   'o',
#   'tabagismo',
#   'continuam',
#   'a',
#   'ser',
#   'um',
#   'grande',
#   'fardo',
#   'para',
#   'a',
#   'saude',
#   'economica',
#   'estima',
#   'se',
#   'que',
#   'ate',
#   '2020',
#   'a',
#   'fracao',
#   'atribuivel',
#   'a',
#   'populacao',
#   'da',
#   'carga',
#   'de',
#   'cancer',
#   'de',
#   'pulmao',
#   'relacionada',
#   'com',
#   'o',
#   'tabagismo',
#   'no',
#   'brasil',
#   'sera',
#   'de',
#   '83',
#   '3',
#   'em',
#   'homens',
#   'e',
#   '64',
#   '8',
#   'em',
#   'mulheres',
#   '13',
#   'esses',
#   'dados',
#   'sao',
#   'relevantes',
#   'para',
#   'reforcar',
#   'o',
#   'papel',
#   'do',
#   'controle',
#   'local',
#   'do',
#   'tabagismo',
#   'nao',
#   'ha',
#   'dados',
#   'a',
#   'respeito',
#   'da',
#   'prevalencia',
#   'do',
#   'cancer',
#   'de',
#   'pulmao',
#   'relacionado',
#   'com',
#   'outros',
#   'fatores',
#   'de',
#   'risco',
#   'tais',
#   'como',
#   'exposicao',
#   'ao',
#   'amianto',
#   'exposicao',
#   'a',
#   'fumaca',
#   'proveniente',
#   'da',
#   'combustao',
#   'da',
#   'lenha',
#   'no',
#   'domicilio',
#   'e',
#   'exposicao',
#   'ao',
#   'radonio']]

# %%
model = Lemmatization()
lemmatized_list = model.lemmatize(tokenized_text)

# print(lemmatized_list)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-18 02:38:22 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | mwt       | bosque  |
# | lemma     | bosque  |
# =======================
#
# 2022-05-18 02:38:22 INFO: Use device: gpu
# 2022-05-18 02:38:22 INFO: Loading: tokenize
# 2022-05-18 02:38:22 INFO: Loading: mwt
# 2022-05-18 02:38:24 INFO: Loading: lemma
# 2022-05-18 02:38:24 INFO: Done loading processors!
# word: nao 	lemma: nao
# word: ha 	lemma: ha
# word: dados 	lemma: dado
# word: exatos 	lemma: exato
# word: a 	lemma: o
# word: respeito 	lemma: respeito
# word: do 	lemma: do
# word: numero 	lemma: numero
# word: de 	lemma: de
# word: procedimentos 	lemma: procedimento
# word: cirurgicos 	lemma: cirurgico
# word: realizados 	lemma: realizar
# word: para 	lemma: para
# word: tratar 	lemma: tratar
# word: pacientes 	lemma: paciente
# word: com 	lemma: com
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: de 	lemma: de
# word: acordo 	lemma: acordo
# word: com 	lemma: com
# word: o 	lemma: o
# word: departamento 	lemma: departamento
# word: de 	lemma: de
# word: informatica 	lemma: informatica
# word: do 	lemma: do
# word: sus 	lemma: su
# word: um 	lemma: um
# word: banco 	lemma: banco
# word: de 	lemma: de
# word: dados 	lemma: dado
# word: do 	lemma: do
# word: sistema 	lemma: sistema
# word: publico 	lemma: publico
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: que 	lemma: que
# word: cobre 	lemma: cobre
# word: aproximadamente 	lemma: aproximadamente
# word: 75 	lemma: 75
# word: da 	lemma: da
# word: populacao 	lemma: populacao
# word: brasileira 	lemma: brasileiro
# word: uma 	lemma: um
# word: mediana 	lemma: mediana
# word: de 	lemma: de
# word: 964 	lemma: 964
# word: lobectomias 	lemma: lobectomia
# word: e 	lemma: e
# word: segmentectomias 	lemma: segmentectomia
# word: pulmonares 	lemma: pulmonar
# word: foram 	lemma: ser
# word: realizadas 	lemma: realizar
# word: anualmente 	lemma: anualmente
# word: entre 	lemma: entre
# word: 2007 	lemma: 2007
# word: e 	lemma: e
# word: 2014 	lemma: 2014
# word: 52 	lemma: 52
# word: no 	lemma: ele
# word: entanto 	lemma: entanto
# word: ha 	lemma: ha
# word: a 	lemma: o
# word: possibilidade 	lemma: possibilidade
# word: de 	lemma: de
# word: que 	lemma: que
# word: esse 	lemma: esse
# word: numero 	lemma: numero
# word: nao 	lemma: nao
# word: seja 	lemma: ser
# word: exato 	lemma: exato
# word: e 	lemma: e
# word: possivel 	lemma: possivel
# word: que 	lemma: que
# word: lobectomias 	lemma: lobectomia
# word: e 	lemma: e
# word: segmentectomias 	lemma: segmentectomia
# word: tenham 	lemma: ter
# word: sido 	lemma: ser
# word: realizadas 	lemma: realizar
# word: para 	lemma: para
# word: tratar 	lemma: tratar
# word: doencas 	lemma: doenca
# word: que 	lemma: que
# word: nao 	lemma: nao
# word: o 	lemma: o
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: o 	lemma: o
# word: banco 	lemma: banco
# word: de 	lemma: de
# word: dados 	lemma: dado
# word: e 	lemma: e
# word: restrito 	lemma: restringir
# word: ao 	lemma: ao
# word: sistema 	lemma: sistema
# word: publico 	lemma: publico
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: e 	lemma: e
# word: a 	lemma: o
# word: qualidade 	lemma: qualidade
# word: dos 	lemma: dos
# word: dados 	lemma: dado
# word: e 	lemma: e
# word: questionavel 	lemma: questionavel
# word: apenas 	lemma: apenas
# word: uma 	lemma: um
# word: pequena 	lemma: pequeno
# word: proporcao 	lemma: proporcao
# word: de 	lemma: de
# word: pacientes 	lemma: paciente
# word: e 	lemma: e
# word: submetida 	lemma: submetida
# word: a 	lemma: o
# word: cirurgia 	lemma: cirurgia
# word: com 	lemma: com
# word: intencao 	lemma: intencao
# word: curativa 	lemma: curativo
# word: os 	lemma: o
# word: dados 	lemma: dado
# word: sugerem 	lemma: sugerem
# word: que 	lemma: que
# word: aproximadamente 	lemma: aproximadamente
# word: 25 	lemma: 25
# word: dos 	lemma: dos
# word: pacientes 	lemma: paciente
# word: sao 	lemma: sao
# word: submetidos 	lemma: submetido
# word: a 	lemma: o
# word: tratamento 	lemma: tratamento
# word: cirurgico 	lemma: cirurgico
# word: 19 	lemma: 19
# word: 22 	lemma: 22
# word: 23 	lemma: 23
# word: o 	lemma: o
# word: acesso 	lemma: acesso
# word: a 	lemma: o
# word: cirurgia 	lemma: cirurgia
# word: curativa 	lemma: curativo
# word: e 	lemma: e
# word: provavelmente 	lemma: provavelmente
# word: influenciado 	lemma: influenciar
# word: por 	lemma: por
# word: diferencas 	lemma: diferenca
# word: socioeconomicas 	lemma: socioeconomica
# word: performance 	lemma: performance
# word: status 	lemma: status
# word: comorbidades 	lemma: comorbidade
# word: idade 	lemma: idade
# word: avancada 	lemma: avancada
# word: e 	lemma: e
# word: distribuicao 	lemma: distribuicao
# word: geografica 	lemma: geografica
# word: 22 	lemma: 22
# word: segundo 	lemma: segundo
# word: a 	lemma: o
# word: secretaria 	lemma: secretaria
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: do 	lemma: do
# word: estado 	lemma: estado
# word: de 	lemma: de
# word: sao 	lemma: sao
# word: paulo 	lemma: paulo
# word: a 	lemma: o
# word: probabilidade 	lemma: probabilidade
# word: de 	lemma: de
# word: realizacao 	lemma: realizacao
# word: de 	lemma: de
# word: cirurgia 	lemma: cirurgia
# word: e 	lemma: e
# word: menor 	lemma: pequeno
# word: em 	lemma: em
# word: pacientes 	lemma: paciente
# word: com 	lemma: com
# word: menor 	lemma: pequeno
# word: escolaridade 	lemma: escolaridade
# word: atualmente 	lemma: atualmente
# word: existem 	lemma: existir
# word: 763 	lemma: 763
# word: cirurgioes 	lemma: cirurgio
# word: toracicos 	lemma: toracico
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: concentrados 	lemma: concentrado
# word: nas 	lemma: elas
# word: regioes 	lemma: regio
# word: sul 	lemma: sul
# word: e 	lemma: e
# word: sudeste 	lemma: sudeste
# word: do 	lemma: do
# word: pais 	lemma: pai
# word: 53 	lemma: 53
# word: em 	lemma: em
# word: uma 	lemma: um
# word: pesquisa 	lemma: pesquisa
# word: promovida 	lemma: promovida
# word: pela 	lemma: pela
# word: sociedade 	lemma: sociedade
# word: brasileira 	lemma: brasileiro
# word: de 	lemma: de
# word: cirurgia 	lemma: cirurgia
# word: toracica 	lemma: toracica
# word: 51 	lemma: 51
# word: dos 	lemma: dos
# word: participantes 	lemma: participante
# word: disseram 	lemma: dizer
# word: que 	lemma: que
# word: trabalhavam 	lemma: trabalhar
# word: em 	lemma: em
# word: cidades 	lemma: cidade
# word: com 	lemma: com
# word: mais 	lemma: mais
# word: de 	lemma: de
# word: um 	lemma: um
# word: milhao 	lemma: milhao
# word: de 	lemma: de
# word: habitantes 	lemma: habitante
# word: 54 	lemma: 54
# word: portanto 	lemma: portanto
# word: mesmo 	lemma: mesmo
# word: que 	lemma: que
# word: o 	lemma: o
# word: numero 	lemma: numero
# word: absoluto 	lemma: absoluto
# word: de 	lemma: de
# word: cirurgioes 	lemma: cirurgio
# word: toracicos 	lemma: toracico
# word: seja 	lemma: ser
# word: adequado 	lemma: adequado
# word: sua 	lemma: seu
# word: distribuicao 	lemma: distribuicao
# word: e 	lemma: e
# word: motivo 	lemma: motivo
# word: de 	lemma: de
# word: preocupacao 	lemma: preocupacao
# word: cidades 	lemma: cidade
# word: de 	lemma: de
# word: tamanho 	lemma: tamanho
# word: medio 	lemma: medio
# word: e 	lemma: e
# word: regioes 	lemma: regio
# word: densamente 	lemma: densamente
# word: povoadas 	lemma: povoada
# word: no 	lemma: ele
# word: centro 	lemma: centro
# word: norte 	lemma: norte
# word: e 	lemma: e
# word: nordeste 	lemma: nordeste
# word: do 	lemma: do
# word: brasil 	lemma: brasil
# word: estao 	lemma: estao
# word: mal 	lemma: mal
# word: servidas 	lemma: servida
# word: no 	lemma: ele
# word: tocante 	lemma: tocante
# word: a 	lemma: o
# word: cirurgia 	lemma: cirurgia
# word: toracica 	lemma: toracica
# word: a 	lemma: o
# word: cirurgia 	lemma: cirurgia
# word: toracica 	lemma: toracica
# word: videoassistida 	lemma: videoassistida
# word: esta 	lemma: este
# word: crescendo 	lemma: crescendo
# word: rapidamente 	lemma: rapidamente
# word: no 	lemma: ele
# word: pais 	lemma: pai
# word: as 	lemma: o
# word: taxas 	lemma: taxa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: em 	lemma: em
# word: 30 	lemma: 30
# word: dias 	lemma: dia
# word: nas 	lemma: elas
# word: duas 	lemma: dois
# word: maiores 	lemma: grande
# word: series 	lemma: serie
# word: de 	lemma: de
# word: casos 	lemma: caso
# word: cirurgicos 	lemma: cirurgico
# word: relatados 	lemma: relatado
# word: que 	lemma: que
# word: incluiram 	lemma: incluiram
# word: pacientes 	lemma: paciente
# word: submetidos 	lemma: submetido
# word: a 	lemma: o
# word: lobectomia 	lemma: lobectomia
# word: em 	lemma: em
# word: virtude 	lemma: virtude
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: foram 	lemma: ser
# word: de 	lemma: de
# word: 2 	lemma: 2
# word: 9 	lemma: 9
# word: e 	lemma: e
# word: 4 	lemma: 4
# word: 3 	lemma: 3
# word: 55 	lemma: 55
# word: 56 	lemma: 56
# word: grandes 	lemma: grande
# word: series 	lemma: serie
# word: de 	lemma: de
# word: casos 	lemma: caso
# word: internacionais 	lemma: internacional
# word: publicadas 	lemma: publicar
# word: nos 	lemma: nós
# word: anos 	lemma: ano
# word: 2000 	lemma: 2000
# word: revelaram 	lemma: revelar
# word: uma 	lemma: um
# word: taxa 	lemma: taxa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: um 	lemma: um
# word: pouco 	lemma: pouco
# word: menor 	lemma: pequeno
# word: de 	lemma: de
# word: aproximadamente 	lemma: aproximadamente
# word: 1 	lemma: 1
# word: 57 	lemma: 57
# word: esses 	lemma: esse
# word: numeros 	lemma: numero
# word: sugerem 	lemma: sugerem
# word: que 	lemma: que
# word: e 	lemma: e
# word: possivel 	lemma: possivel
# word: melhorar 	lemma: melhorar
# word: a 	lemma: o
# word: cirurgia 	lemma: cirurgia
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: espera 	lemma: esperar
# word: se 	lemma: se
# word: que 	lemma: que
# word: a 	lemma: o
# word: disseminacao 	lemma: disseminacao
# word: e 	lemma: e
# word: disponibilidade 	lemma: disponibilidade
# word: de 	lemma: de
# word: novas 	lemma: novo
# word: tecnicas 	lemma: tecnica
# word: tais 	lemma: tal
# word: como 	lemma: como
# word: a 	lemma: o
# word: cirurgia 	lemma: cirurgia
# word: videoassistida 	lemma: videoassistida
# word: e 	lemma: e
# word: a 	lemma: o
# word: cirurgia 	lemma: cirurgia
# word: robotica 	lemma: robotica
# word: acelerem 	lemma: acelerem
# word: esse 	lemma: esse
# word: processo 	lemma: processo
# word: embora 	lemma: embora
# word: haja 	lemma: haver
# word: relativamente 	lemma: relativamente
# word: poucos 	lemma: pouco
# word: dados 	lemma: dado
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: a 	lemma: o
# word: respeito 	lemma: respeito
# word: de 	lemma: de
# word: como 	lemma: como
# word: o 	lemma: o
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: e 	lemma: e
# word: diagnosticado 	lemma: diagnosticado
# word: e 	lemma: e
# word: classificado 	lemma: classificado
# word: foram 	lemma: ser
# word: publicados 	lemma: publicar
# word: alguns 	lemma: algum
# word: dados 	lemma: dado
# word: nos 	lemma: nós
# word: ultimos 	lemma: ultimo
# word: 15 	lemma: 15
# word: anos 	lemma: ano
# word: assim 	lemma: assim
# word: como 	lemma: como
# word: ocorre 	lemma: ocorrer
# word: em 	lemma: em
# word: paises 	lemma: pais
# word: desenvolvidos 	lemma: desenvolver
# word: o 	lemma: o
# word: cancer 	lemma: cancer
# word: pulmonar 	lemma: pulmonar
# word: de 	lemma: de
# word: celulas 	lemma: celula
# word: nao 	lemma: nao
# word: pequenas 	lemma: pequeno
# word: cpcnp 	lemma: cpcnp
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: e 	lemma: e
# word: geralmente 	lemma: geralmente
# word: diagnosticado 	lemma: diagnosticado
# word: em 	lemma: em
# word: estagios 	lemma: estagio
# word: avancados 	lemma: avancado
# word: e 	lemma: e
# word: apresenta 	lemma: apresentar
# word: baixas 	lemma: baixo
# word: taxas 	lemma: taxa
# word: de 	lemma: de
# word: sobrevida 	lemma: sobrevido
# word: no 	lemma: ele
# word: geral 	lemma: geral
# word: aproximadamente 	lemma: aproximadamente
# word: 70 	lemma: 70
# word: dos 	lemma: dos
# word: pacientes 	lemma: paciente
# word: apresentam 	lemma: apresentar
# word: doenca 	lemma: doenca
# word: localmente 	lemma: localmente
# word: avancada 	lemma: avancada
# word: ou 	lemma: ou
# word: metastatica 	lemma: metastatica
# word: estagio 	lemma: estagio
# word: iii 	lemma: iii
# word: e 	lemma: e
# word: iv 	lemma: iv
# word: respectivamente 	lemma: respectivamente
# word: de 	lemma: de
# word: acordo 	lemma: acordo
# word: com 	lemma: com
# word: um 	lemma: um
# word: grande 	lemma: grande
# word: banco 	lemma: banco
# word: de 	lemma: de
# word: dados 	lemma: dado
# word: de 	lemma: de
# word: casos 	lemma: caso
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: no 	lemma: ele
# word: estado 	lemma: estado
# word: de 	lemma: de
# word: sao 	lemma: sao
# word: paulo 	lemma: paulo
# word: apenas 	lemma: apenas
# word: 8 	lemma: 8
# word: 8 	lemma: 8
# word: dos 	lemma: dos
# word: 20 	lemma: 20
# word: 850 	lemma: 850
# word: pacientes 	lemma: paciente
# word: com 	lemma: com
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: registrados 	lemma: registrar
# word: no 	lemma: ele
# word: sistema 	lemma: sistema
# word: entre 	lemma: entre
# word: 2000 	lemma: 2000
# word: e 	lemma: e
# word: 2010 	lemma: 2010
# word: apresentavam 	lemma: apresentar
# word: doenca 	lemma: doenca
# word: no 	lemma: ele
# word: estagio 	lemma: estagio
# word: i 	lemma: i
# word: 14 	lemma: 14
# word: essas 	lemma: esse
# word: porcentagens 	lemma: porcentagem
# word: contrastam 	lemma: contrastam
# word: com 	lemma: com
# word: as 	lemma: o
# word: de 	lemma: de
# word: 15 	lemma: 15
# word: 4 	lemma: 4
# word: e 	lemma: e
# word: 14 	lemma: 14
# word: 5 	lemma: 5
# word: referentes 	lemma: referente
# word: a 	lemma: o
# word: um 	lemma: um
# word: periodo 	lemma: periodo
# word: semelhante 	lemma: semelhante
# word: nos 	lemma: nós
# word: eua 	lemma: eua
# word: e 	lemma: e
# word: no 	lemma: ele
# word: reino 	lemma: reino
# word: unido 	lemma: unir
# word: respectivamente 	lemma: respectivamente
# word: 15 	lemma: 15
# word: 16 	lemma: 16
# word: um 	lemma: um
# word: ensaio 	lemma: ensaio
# word: brasileiro 	lemma: brasileiro
# word: de 	lemma: de
# word: rastreamento 	lemma: rastreamento
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: foi 	lemma: ser
# word: realizado 	lemma: realizar
# word: a 	lemma: o
# word: fim 	lemma: fim
# word: de 	lemma: de
# word: determinar 	lemma: determinar
# word: a 	lemma: o
# word: eficacia 	lemma: eficacia
# word: do 	lemma: do
# word: rastreamento 	lemma: rastreamento
# word: no 	lemma: ele
# word: pais 	lemma: pai
# word: 17 	lemma: 17
# word: entre 	lemma: entre
# word: janeiro 	lemma: janeiro
# word: de 	lemma: de
# word: 2013 	lemma: 2013
# word: e 	lemma: e
# word: julho 	lemma: julho
# word: de 	lemma: de
# word: 2014 	lemma: 2014
# word: 790 	lemma: 790
# word: voluntarios 	lemma: voluntario
# word: se 	lemma: se
# word: ofereceram 	lemma: oferecer
# word: para 	lemma: para
# word: participar 	lemma: participar
# word: do 	lemma: do
# word: estudo 	lemma: estudo
# word: cujos 	lemma: cujo
# word: criterios 	lemma: criterio
# word: de 	lemma: de
# word: elegibilidade 	lemma: elegibilidade
# word: foram 	lemma: ser
# word: os 	lemma: o
# word: mesmos 	lemma: mesmo
# word: que 	lemma: que
# word: os 	lemma: o
# word: aplicados 	lemma: aplicar
# word: em 	lemma: em
# word: um 	lemma: um
# word: ensaio 	lemma: ensaio
# word: nacional 	lemma: nacional
# word: de 	lemma: de
# word: rastreamento 	lemma: rastreamento
# word: pulmonar 	lemma: pulmonar
# word: realizado 	lemma: realizar
# word: nos 	lemma: nós
# word: eua 	lemma: eua
# word: do 	lemma: do
# word: total 	lemma: total
# word: de 	lemma: de
# word: participantes 	lemma: participante
# word: 10 	lemma: 10
# word: receberam 	lemma: receber
# word: o 	lemma: o
# word: diagnostico 	lemma: diagnostico
# word: de 	lemma: de
# word: cpcnp 	lemma: cpcnp
# word: prevalencia 	lemma: prevalencia
# word: de 	lemma: de
# word: 1 	lemma: 1
# word: 3 	lemma: 3
# word: a 	lemma: o
# word: maioria 	lemma: maioria
# word: dos 	lemma: dos
# word: quais 	lemma: qual
# word: foi 	lemma: ser
# word: classificada 	lemma: classificado
# word: em 	lemma: em
# word: estagio 	lemma: estagio
# word: i 	lemma: i
# word: 17 	lemma: 17
# word: foram 	lemma: ser
# word: publicadas 	lemma: publicar
# word: varias 	lemma: varias
# word: series 	lemma: serie
# word: retrospectivas 	lemma: retrospectiva
# word: nas 	lemma: elas
# word: quais 	lemma: qual
# word: foram 	lemma: ser
# word: relatados 	lemma: relatado
# word: dados 	lemma: dado
# word: provenientes 	lemma: proveniente
# word: de 	lemma: de
# word: uma 	lemma: um
# word: unica 	lemma: unica
# word: instituicao 	lemma: instituicao
# word: a 	lemma: o
# word: respeito 	lemma: respeito
# word: da 	lemma: da
# word: histologia 	lemma: histologia
# word: estadiamento 	lemma: estadiamento
# word: e 	lemma: e
# word: desfechos 	lemma: desfecho
# word: do 	lemma: do
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: 18 	lemma: 18
# word: 26 	lemma: 26
# word: curiosamente 	lemma: curiosamente
# word: a 	lemma: o
# word: presenca 	lemma: presenca
# word: de 	lemma: de
# word: celulas 	lemma: celula
# word: escamosas 	lemma: escamosa
# word: no 	lemma: ele
# word: exame 	lemma: exame
# word: histologico 	lemma: histologico
# word: parece 	lemma: parecer
# word: ser 	lemma: ser
# word: mais 	lemma: mais
# word: prevalente 	lemma: prevalente
# word: em 	lemma: em
# word: servicos 	lemma: servico
# word: publicos 	lemma: publico
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: ao 	lemma: ao
# word: passo 	lemma: passo
# word: que 	lemma: que
# word: o 	lemma: o
# word: adenocarcinoma 	lemma: adenocarcinoma
# word: predomina 	lemma: predomina
# word: em 	lemma: em
# word: instituicoes 	lemma: instituico
# word: privadas 	lemma: privar
# word: nos 	lemma: nós
# word: eua 	lemma: eua
# word: as 	lemma: o
# word: taxas 	lemma: taxa
# word: de 	lemma: de
# word: carcinoma 	lemma: carcinoma
# word: de 	lemma: de
# word: celulas 	lemma: celula
# word: escamosas 	lemma: escamosa
# word: e 	lemma: e
# word: carcinoma 	lemma: carcinoma
# word: de 	lemma: de
# word: pequenas 	lemma: pequeno
# word: celulas 	lemma: celula
# word: do 	lemma: do
# word: pulmao 	lemma: pulmao
# word: cpcp 	lemma: cpcp
# word: diminuiram 	lemma: diminuiram
# word: apos 	lemma: apos
# word: a 	lemma: o
# word: decada 	lemma: decada
# word: de 	lemma: de
# word: 1990 	lemma: 1990
# word: e 	lemma: e
# word: as 	lemma: o
# word: taxas 	lemma: taxa
# word: de 	lemma: de
# word: adenocarcinoma 	lemma: adenocarcinoma
# word: aumentaram 	lemma: aumentar
# word: no 	lemma: ele
# word: periodo 	lemma: periodo
# word: entre 	lemma: entre
# word: 2006 	lemma: 2006
# word: e 	lemma: e
# word: 2010 	lemma: 2010
# word: em 	lemma: em
# word: todas 	lemma: todo
# word: as 	lemma: o
# word: racas 	lemma: raca
# word: etnias 	lemma: etnia
# word: sexos 	lemma: sexo
# word: 27 	lemma: 27
# word: um 	lemma: um
# word: importante 	lemma: importante
# word: centro 	lemma: centro
# word: oncologico 	lemma: oncologico
# word: no 	lemma: ele
# word: estado 	lemma: estado
# word: de 	lemma: de
# word: sao 	lemma: sao
# word: paulo 	lemma: paulo
# word: analisou 	lemma: analisou
# word: dados 	lemma: dado
# word: coletados 	lemma: coletado
# word: entre 	lemma: entre
# word: 1997 	lemma: 1997
# word: e 	lemma: e
# word: 2008 	lemma: 2008
# word: referentes 	lemma: referente
# word: a 	lemma: o
# word: 1 	lemma: 1
# word: 887 	lemma: 887
# word: pacientes 	lemma: paciente
# word: com 	lemma: com
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: 18 	lemma: 18
# word: houve 	lemma: haver
# word: uma 	lemma: um
# word: queda 	lemma: queda
# word: da 	lemma: da
# word: proporcao 	lemma: proporcao
# word: de 	lemma: de
# word: cpcp 	lemma: cpcp
# word: em 	lemma: em
# word: dois 	lemma: dois
# word: periodo 	lemma: periodo
# word: diferentes 	lemma: diferente
# word: 1997 	lemma: 1997
# word: 2002 	lemma: 2002
# word: e 	lemma: e
# word: 2003 	lemma: 2003
# word: 2008 	lemma: 2008
# word: embora 	lemma: embora
# word: nao 	lemma: nao
# word: tenham 	lemma: ter
# word: ocorrido 	lemma: ocorrer
# word: alteracoes 	lemma: alteraco
# word: significativas 	lemma: significativo
# word: nos 	lemma: nós
# word: subgrupos 	lemma: subgrupo
# word: histologicos 	lemma: histologico
# word: de 	lemma: de
# word: cpcnp 	lemma: cpcnp
# word: 18 	lemma: 18
# word: no 	lemma: ele
# word: entanto 	lemma: entanto
# word: em 	lemma: em
# word: um 	lemma: um
# word: estudo 	lemma: estudo
# word: epidemiologico 	lemma: epidemiologico
# word: no 	lemma: ele
# word: qual 	lemma: qual
# word: foram 	lemma: ser
# word: avaliados 	lemma: avaliado
# word: dados 	lemma: dado
# word: de 	lemma: de
# word: casos 	lemma: caso
# word: de 	lemma: de
# word: 35 	lemma: 35
# word: 018 	lemma: 018
# word: pacientes 	lemma: paciente
# word: com 	lemma: com
# word: diagnostico 	lemma: diagnostico
# word: de 	lemma: de
# word: cpcnp 	lemma: cpcnp
# word: nos 	lemma: nós
# word: estados 	lemma: estado
# word: do 	lemma: do
# word: rio 	lemma: rio
# word: de 	lemma: de
# word: janeiro 	lemma: janeiro
# word: e 	lemma: e
# word: sao 	lemma: sao
# word: paulo 	lemma: paulo
# word: entre 	lemma: entre
# word: 2000 	lemma: 2000
# word: e 	lemma: e
# word: 2011 	lemma: 2011
# word: observou 	lemma: observar
# word: se 	lemma: se
# word: uma 	lemma: um
# word: tendencia 	lemma: tendencia
# word: a 	lemma: o
# word: maior 	lemma: grande
# word: prevalencia 	lemma: prevalencia
# word: de 	lemma: de
# word: adenocarcinoma 	lemma: adenocarcinoma
# word: que 	lemma: que
# word: de 	lemma: de
# word: carcinoma 	lemma: carcinoma
# word: de 	lemma: de
# word: celulas 	lemma: celula
# word: escamosas 	lemma: escamosa
# word: no 	lemma: ele
# word: exame 	lemma: exame
# word: histologico 	lemma: histologico
# word: nos 	lemma: nós
# word: ultimos 	lemma: ultimo
# word: anos 	lemma: ano
# word: 43 	lemma: 43
# word: 3 	lemma: 3
# word: vs 	lemma: vs
# word: 36 	lemma: 36
# word: 5 	lemma: 5
# word: o 	lemma: o
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: e 	lemma: e
# word: a 	lemma: o
# word: doenca 	lemma: doenca
# word: maligna 	lemma: maligna
# word: mais 	lemma: mais
# word: comum 	lemma: comum
# word: em 	lemma: em
# word: todo 	lemma: todo
# word: o 	lemma: o
# word: mundo 	lemma: mundo
# word: de 	lemma: de
# word: todos 	lemma: todo
# word: os 	lemma: o
# word: novos 	lemma: novo
# word: casos 	lemma: caso
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: 13 	lemma: 13
# word: sao 	lemma: sao
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: 1 	lemma: 1
# word: de 	lemma: de
# word: acordo 	lemma: acordo
# word: com 	lemma: com
# word: o 	lemma: o
# word: global 	lemma: global
# word: burden 	lemma: burden
# word: of 	lemma: of
# word: disease 	lemma: disease
# word: study 	lemma: study
# word: 2015 	lemma: 2015
# word: o 	lemma: o
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: e 	lemma: e
# word: tambem 	lemma: tambem
# word: a 	lemma: o
# word: principal 	lemma: principal
# word: causa 	lemma: causa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: por 	lemma: por
# word: cancer 	lemma: cancer
# word: mais 	lemma: mais
# word: de 	lemma: de
# word: 1 	lemma: 1
# word: 7 	lemma: 7
# word: 1 	lemma: 1
# word: 8 	lemma: 8
# word: milhoes 	lemma: milho
# word: de 	lemma: de
# word: mortes 	lemma: morte
# word: por 	lemma: por
# word: ano 	lemma: ano
# word: e 	lemma: e
# word: de 	lemma: de
# word: todos 	lemma: todo
# word: os 	lemma: o
# word: tipos 	lemma: tipo
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: o 	lemma: o
# word: que 	lemma: que
# word: apresenta 	lemma: apresentar
# word: a 	lemma: o
# word: maior 	lemma: grande
# word: taxa 	lemma: taxa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: padronizada 	lemma: padronizada
# word: pela 	lemma: pela
# word: idade 	lemma: idade
# word: 26 	lemma: 26
# word: 6 	lemma: 6
# word: mortes 	lemma: morte
# word: por 	lemma: por
# word: 100 	lemma: 100
# word: 000 	lemma: 000
# word: habitantes 	lemma: habitante
# word: 2 	lemma: 2
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: o 	lemma: o
# word: instituto 	lemma: instituto
# word: nacional 	lemma: nacional
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: inca 	lemma: inca
# word: estimou 	lemma: estimou
# word: em 	lemma: em
# word: 596 	lemma: 596
# word: 000 	lemma: 000
# word: o 	lemma: o
# word: numero 	lemma: numero
# word: de 	lemma: de
# word: novos 	lemma: novo
# word: casos 	lemma: caso
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: em 	lemma: em
# word: 2016 	lemma: 2016
# word: 28 	lemma: 28
# word: 220 	lemma: 220
# word: 4 	lemma: 4
# word: 7 	lemma: 7
# word: dos 	lemma: dos
# word: quais 	lemma: qual
# word: foram 	lemma: ser
# word: casos 	lemma: caso
# word: de 	lemma: de
# word: neoplasia 	lemma: neoplasia
# word: maligna 	lemma: maligna
# word: primaria 	lemma: primaria
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: 3 	lemma: 3
# word: o 	lemma: o
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: e 	lemma: e
# word: o 	lemma: o
# word: segundo 	lemma: segundo
# word: tipo 	lemma: tipo
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: maior 	lemma: grande
# word: incidencia 	lemma: incidencia
# word: em 	lemma: em
# word: homens 	lemma: homem
# word: e 	lemma: e
# word: o 	lemma: o
# word: quarto 	lemma: quarto
# word: tipo 	lemma: tipo
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: maior 	lemma: grande
# word: incidencia 	lemma: incidencia
# word: em 	lemma: em
# word: mulheres 	lemma: mulher
# word: no 	lemma: ele
# word: pais 	lemma: pai
# word: figura 	lemma: figura
# word: 1 	lemma: 1
# word: 3 	lemma: 3
# word: como 	lemma: como
# word: na 	lemma: ela
# word: maioria 	lemma: maioria
# word: dos 	lemma: dos
# word: paises 	lemma: pais
# word: o 	lemma: o
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: e 	lemma: e
# word: a 	lemma: o
# word: principal 	lemma: principal
# word: causa 	lemma: causa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: por 	lemma: por
# word: cancer 	lemma: cancer
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: a 	lemma: o
# word: taxa 	lemma: taxa
# word: de 	lemma: de
# word: sobrevida 	lemma: sobrevido
# word: em 	lemma: em
# word: 5 	lemma: 5
# word: anos 	lemma: ano
# word: padronizada 	lemma: padronizada
# word: pela 	lemma: pela
# word: idade 	lemma: idade
# word: no 	lemma: ele
# word: pais 	lemma: pai
# word: e 	lemma: e
# word: de 	lemma: de
# word: 18 	lemma: 18
# word: semelhante 	lemma: semelhante
# word: as 	lemma: o
# word: taxas 	lemma: taxa
# word: globais 	lemma: global
# word: que 	lemma: que
# word: variam 	lemma: variar
# word: de 	lemma: de
# word: 10 	lemma: 10
# word: a 	lemma: o
# word: 20 	lemma: 20
# word: 4 	lemma: 4
# word: em 	lemma: em
# word: 2012 	lemma: 2012
# word: as 	lemma: o
# word: taxas 	lemma: taxa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: por 	lemma: por
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: padronizadas 	lemma: padronizada
# word: pela 	lemma: pela
# word: idade 	lemma: idade
# word: foram 	lemma: ser
# word: de 	lemma: de
# word: 16 	lemma: 16
# word: 5 	lemma: 5
# word: mortes 	lemma: morte
# word: 100 	lemma: 100
# word: 000 	lemma: 000
# word: habitantes 	lemma: habitante
# word: e 	lemma: e
# word: 8 	lemma: 8
# word: 6 	lemma: 6
# word: mortes 	lemma: morte
# word: 100 	lemma: 100
# word: 000 	lemma: 000
# word: habitantes 	lemma: habitante
# word: em 	lemma: em
# word: homens 	lemma: homem
# word: e 	lemma: e
# word: mulheres 	lemma: mulher
# word: respectivamente 	lemma: respectivamente
# word: 5 	lemma: 5
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: de 	lemma: de
# word: 1979 	lemma: 1979
# word: a 	lemma: o
# word: 2004 	lemma: 2004
# word: a 	lemma: o
# word: mortalidade 	lemma: mortalidade
# word: aumentou 	lemma: aumentar
# word: de 	lemma: de
# word: 10 	lemma: 10
# word: 6 	lemma: 6
# word: mortes 	lemma: morte
# word: 100 	lemma: 100
# word: 000 	lemma: 000
# word: habitantes 	lemma: habitante
# word: para 	lemma: para
# word: 31 	lemma: 31
# word: 1 	lemma: 1
# word: mortes 	lemma: morte
# word: 100 	lemma: 100
# word: 000 	lemma: 000
# word: habitantes 	lemma: habitante
# word: em 	lemma: em
# word: homens 	lemma: homem
# word: e 	lemma: e
# word: de 	lemma: de
# word: 3 	lemma: 3
# word: 0 	lemma: 0
# word: mortes 	lemma: morte
# word: 100 	lemma: 100
# word: 000 	lemma: 000
# word: habitantes 	lemma: habitante
# word: para 	lemma: para
# word: 5 	lemma: 5
# word: 4 	lemma: 4
# word: mortes 	lemma: morte
# word: 100 	lemma: 100
# word: 000 	lemma: 000
# word: habitantes 	lemma: habitante
# word: em 	lemma: em
# word: mulheres 	lemma: mulher
# word: 6 	lemma: 6
# word: as 	lemma: o
# word: taxas 	lemma: taxa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: tanto 	lemma: tanto
# word: as 	lemma: o
# word: brutas 	lemma: bruto
# word: como 	lemma: como
# word: as 	lemma: o
# word: ajustadas 	lemma: ajustada
# word: pela 	lemma: pela
# word: idade 	lemma: idade
# word: em 	lemma: em
# word: homens 	lemma: homem
# word: e 	lemma: e
# word: mulheres 	lemma: mulher
# word: diferiram 	lemma: diferiram
# word: em 	lemma: em
# word: magnitude 	lemma: magnitude
# word: em 	lemma: em
# word: todos 	lemma: todo
# word: os 	lemma: o
# word: periodos 	lemma: periodo
# word: 1980 	lemma: 1980
# word: 2007 	lemma: 2007
# word: com 	lemma: com
# word: um 	lemma: um
# word: aumento 	lemma: aumento
# word: relativo 	lemma: relativo
# word: mais 	lemma: mais
# word: significativo 	lemma: significativo
# word: nas 	lemma: elas
# word: mulheres 	lemma: mulher
# word: que 	lemma: que
# word: nos 	lemma: nós
# word: homens 	lemma: homem
# word: 78 	lemma: 78
# word: 4 	lemma: 4
# word: vs 	lemma: vs
# word: 8 	lemma: 8
# word: 2 	lemma: 2
# word: provavelmente 	lemma: provavelmente
# word: em 	lemma: em
# word: virtude 	lemma: virtude
# word: de 	lemma: de
# word: diferencas 	lemma: diferenca
# word: na 	lemma: ela
# word: prevalencia 	lemma: prevalencia
# word: do 	lemma: do
# word: tabagismo 	lemma: tabagismo
# word: figura 	lemma: figura
# word: 2 	lemma: 2
# word: alem 	lemma: alem
# word: disso 	lemma: disso
# word: as 	lemma: o
# word: taxas 	lemma: taxa
# word: de 	lemma: de
# word: mortalidade 	lemma: mortalidade
# word: por 	lemma: por
# word: idade 	lemma: idade
# word: aumentaram 	lemma: aumentar
# word: em 	lemma: em
# word: homens 	lemma: homem
# word: com 	lemma: com
# word: idade 	lemma: idade
# word: igual 	lemma: igual
# word: ou 	lemma: ou
# word: superior 	lemma: alto
# word: a 	lemma: o
# word: 65 	lemma: 65
# word: anos 	lemma: ano
# word: e 	lemma: e
# word: em 	lemma: em
# word: mulheres 	lemma: mulher
# word: de 	lemma: de
# word: todas 	lemma: todo
# word: as 	lemma: o
# word: idades 	lemma: idade
# word: 7 	lemma: 7
# word: o 	lemma: o
# word: sistema 	lemma: sistema
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: brasileiro 	lemma: brasileiro
# word: e 	lemma: e
# word: dividido 	lemma: dividir
# word: em 	lemma: em
# word: cobertura 	lemma: cobertura
# word: privada 	lemma: privado
# word: e 	lemma: e
# word: cobertura 	lemma: cobertura
# word: publica 	lemma: publicar
# word: 27 	lemma: 27
# word: e 	lemma: e
# word: 73 	lemma: 73
# word: respectivamente 	lemma: respectivamente
# word: como 	lemma: como
# word: sera 	lemma: sera
# word: discutido 	lemma: discutir
# word: mais 	lemma: mais
# word: adiante 	lemma: adiante
# word: na 	lemma: ela
# word: presente 	lemma: presente
# word: analise 	lemma: analise
# word: e 	lemma: e
# word: evidente 	lemma: evidente
# word: que 	lemma: que
# word: ha 	lemma: ha
# word: discrepancia 	lemma: discrepancia
# word: significativa 	lemma: significativo
# word: entre 	lemma: entre
# word: o 	lemma: o
# word: sistema 	lemma: sistema
# word: publico 	lemma: publico
# word: e 	lemma: e
# word: o 	lemma: o
# word: privado 	lemma: privado
# word: no 	lemma: ele
# word: tocante 	lemma: tocante
# word: a 	lemma: o
# word: disponibilidade 	lemma: disponibilidade
# word: de 	lemma: de
# word: recursos 	lemma: recurso
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: e 	lemma: e
# word: aos 	lemma: aos
# word: desfechos 	lemma: desfecho
# word: dos 	lemma: dos
# word: paciente 	lemma: paciente
# word: as 	lemma: o
# word: tendencias 	lemma: tendencia
# word: da 	lemma: da
# word: mortalidade 	lemma: mortalidade
# word: por 	lemma: por
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: refletem 	lemma: refletir
# word: o 	lemma: o
# word: modelo 	lemma: modelo
# word: epidemiologico 	lemma: epidemiologico
# word: da 	lemma: da
# word: mortalidade 	lemma: mortalidade
# word: relacionada 	lemma: relacionado
# word: com 	lemma: com
# word: o 	lemma: o
# word: tabaco 	lemma: tabaco
# word: o 	lemma: o
# word: uso 	lemma: uso
# word: do 	lemma: do
# word: tabaco 	lemma: tabaco
# word: aumentou 	lemma: aumentar
# word: durante 	lemma: durante
# word: as 	lemma: o
# word: decadas 	lemma: decada
# word: de 	lemma: de
# word: 1950 	lemma: 1950
# word: e 	lemma: e
# word: 1960 	lemma: 1960
# word: e 	lemma: e
# word: atingiu 	lemma: atingir
# word: o 	lemma: o
# word: ponto 	lemma: ponto
# word: maximo 	lemma: maximo
# word: na 	lemma: ela
# word: decada 	lemma: decada
# word: de 	lemma: de
# word: 1970 	lemma: 1970
# word: fortes 	lemma: forte
# word: politicas 	lemma: politica
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: publica 	lemma: publicar
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: resultaram 	lemma: resultar
# word: em 	lemma: em
# word: reducao 	lemma: reducao
# word: do 	lemma: do
# word: consumo 	lemma: consumo
# word: de 	lemma: de
# word: tabaco 	lemma: tabaco
# word: o 	lemma: o
# word: que 	lemma: que
# word: pode 	lemma: poder
# word: servir 	lemma: servir
# word: de 	lemma: de
# word: exemplo 	lemma: exemplo
# word: para 	lemma: para
# word: outros 	lemma: outro
# word: paises 	lemma: pais
# word: de 	lemma: de
# word: baixa 	lemma: baixa
# word: e 	lemma: e
# word: media 	lemma: media
# word: renda 	lemma: renda
# word: estudos 	lemma: estudo
# word: conduzidos 	lemma: conduzir
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: indicam 	lemma: indicar
# word: que 	lemma: que
# word: tanto 	lemma: tanto
# word: a 	lemma: o
# word: prevalencia 	lemma: prevalencia
# word: do 	lemma: do
# word: tabagismo 	lemma: tabagismo
# word: como 	lemma: como
# word: as 	lemma: o
# word: mortes 	lemma: morte
# word: com 	lemma: com
# word: ele 	lemma: ele
# word: relacionadas 	lemma: relacionar
# word: diminuiram 	lemma: diminuiram
# word: aproximadamente 	lemma: aproximadamente
# word: 50 	lemma: 50
# word: 9 	lemma: 9
# word: os 	lemma: o
# word: dados 	lemma: dado
# word: provenientes 	lemma: proveniente
# word: de 	lemma: de
# word: um 	lemma: um
# word: estudo 	lemma: estudo
# word: nacional 	lemma: nacional
# word: de 	lemma: de
# word: vigilancia 	lemma: vigilancia
# word: por 	lemma: por
# word: telefone 	lemma: telefone
# word: sobre 	lemma: sobre
# word: fatores 	lemma: fator
# word: de 	lemma: de
# word: risco 	lemma: risco
# word: de 	lemma: de
# word: doencas 	lemma: doenca
# word: cronicas 	lemma: cronica
# word: e 	lemma: e
# word: fatores 	lemma: fator
# word: de 	lemma: de
# word: protecao 	lemma: protecao
# word: contra 	lemma: contra
# word: essas 	lemma: esse
# word: doencas 	lemma: doenca
# word: mostraram 	lemma: mostraram
# word: que 	lemma: que
# word: 12 	lemma: 12
# word: 7 	lemma: 7
# word: dos 	lemma: dos
# word: homens 	lemma: homem
# word: e 	lemma: e
# word: 8 	lemma: 8
# word: 0 	lemma: 0
# word: das 	lemma: das
# word: mulheres 	lemma: mulher
# word: com 	lemma: com
# word: 18 	lemma: 18
# word: anos 	lemma: ano
# word: de 	lemma: de
# word: idade 	lemma: idade
# word: ou 	lemma: ou
# word: mais 	lemma: mais
# word: eram 	lemma: ser
# word: fumantes 	lemma: fumante
# word: em 	lemma: em
# word: 2016 	lemma: 2016
# word: 10 	lemma: 10
# word: em 	lemma: em
# word: 1989 	lemma: 1989
# word: as 	lemma: o
# word: porcentagens 	lemma: porcentagem
# word: eram 	lemma: ser
# word: de 	lemma: de
# word: 43 	lemma: 43
# word: 3 	lemma: 3
# word: e 	lemma: e
# word: 27 	lemma: 27
# word: 0 	lemma: 0
# word: respectivamente 	lemma: respectivamente
# word: os 	lemma: o
# word: principais 	lemma: principal
# word: componentes 	lemma: componente
# word: das 	lemma: das
# word: politicas 	lemma: politica
# word: brasileiras 	lemma: brasileiro
# word: antitabaco 	lemma: antitabaco
# word: sao 	lemma: sao
# word: a 	lemma: o
# word: proibicao 	lemma: proibicao
# word: do 	lemma: do
# word: tabagismo 	lemma: tabagismo
# word: em 	lemma: em
# word: locais 	lemma: local
# word: publicos 	lemma: publico
# word: impostos 	lemma: imposto
# word: mais 	lemma: mais
# word: altos 	lemma: alto
# word: sobre 	lemma: sobre
# word: produtos 	lemma: produto
# word: do 	lemma: do
# word: tabaco 	lemma: tabaco
# word: e 	lemma: e
# word: alertas 	lemma: alerta
# word: de 	lemma: de
# word: saude 	lemma: saude
# word: nos 	lemma: nós
# word: rotulos 	lemma: rotulo
# word: das 	lemma: das
# word: embalagens 	lemma: embalagem
# word: de 	lemma: de
# word: cigarros 	lemma: cigarro
# word: apesar 	lemma: apesar
# word: dessa 	lemma: dessa
# word: diminuicao 	lemma: diminuicao
# word: do 	lemma: do
# word: consumo 	lemma: consumo
# word: de 	lemma: de
# word: tabaco 	lemma: tabaco
# word: pesquisas 	lemma: pesquisa
# word: nacionais 	lemma: nacional
# word: com 	lemma: com
# word: criancas 	lemma: crianca
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: ainda 	lemma: ainda
# word: mostram 	lemma: mostrar
# word: uma 	lemma: um
# word: prevalencia 	lemma: prevalencia
# word: significativa 	lemma: significativo
# word: de 	lemma: de
# word: fumantes 	lemma: fumante
# word: na 	lemma: ela
# word: populacao 	lemma: populacao
# word: jovem 	lemma: jovem
# word: em 	lemma: em
# word: diversas 	lemma: diversos
# word: cidades 	lemma: cidade
# word: alem 	lemma: alem
# word: disso 	lemma: disso
# word: as 	lemma: o
# word: doencas 	lemma: doenca
# word: relacionadas 	lemma: relacionar
# word: com 	lemma: com
# word: o 	lemma: o
# word: tabagismo 	lemma: tabagismo
# word: continuam 	lemma: continuar
# word: a 	lemma: o
# word: ser 	lemma: ser
# word: um 	lemma: um
# word: grande 	lemma: grande
# word: fardo 	lemma: fardo
# word: para 	lemma: para
# word: a 	lemma: o
# word: saude 	lemma: saude
# word: economica 	lemma: economica
# word: estima 	lemma: estimar
# word: se 	lemma: se
# word: que 	lemma: que
# word: ate 	lemma: ate
# word: 2020 	lemma: 2020
# word: a 	lemma: o
# word: fracao 	lemma: fracao
# word: atribuivel 	lemma: atribuivel
# word: a 	lemma: o
# word: populacao 	lemma: populacao
# word: da 	lemma: da
# word: carga 	lemma: carga
# word: de 	lemma: de
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: relacionada 	lemma: relacionado
# word: com 	lemma: com
# word: o 	lemma: o
# word: tabagismo 	lemma: tabagismo
# word: no 	lemma: ele
# word: brasil 	lemma: brasil
# word: sera 	lemma: sera
# word: de 	lemma: de
# word: 83 	lemma: 83
# word: 3 	lemma: 3
# word: em 	lemma: em
# word: homens 	lemma: homem
# word: e 	lemma: e
# word: 64 	lemma: 64
# word: 8 	lemma: 8
# word: em 	lemma: em
# word: mulheres 	lemma: mulher
# word: 13 	lemma: 13
# word: esses 	lemma: esse
# word: dados 	lemma: dado
# word: sao 	lemma: sao
# word: relevantes 	lemma: relevante
# word: para 	lemma: para
# word: reforcar 	lemma: reforcar
# word: o 	lemma: o
# word: papel 	lemma: papel
# word: do 	lemma: do
# word: controle 	lemma: controle
# word: local 	lemma: local
# word: do 	lemma: do
# word: tabagismo 	lemma: tabagismo
# word: nao 	lemma: nao
# word: ha 	lemma: ha
# word: dados 	lemma: dado
# word: a 	lemma: o
# word: respeito 	lemma: respeito
# word: da 	lemma: da
# word: prevalencia 	lemma: prevalencia
# word: do 	lemma: do
# word: cancer 	lemma: cancer
# word: de 	lemma: de
# word: pulmao 	lemma: pulmao
# word: relacionado 	lemma: relacionar
# word: com 	lemma: com
# word: outros 	lemma: outro
# word: fatores 	lemma: fator
# word: de 	lemma: de
# word: risco 	lemma: risco
# word: tais 	lemma: tal
# word: como 	lemma: como
# word: exposicao 	lemma: exposicao
# word: ao 	lemma: ao
# word: amianto 	lemma: amianto
# word: exposicao 	lemma: exposicao
# word: a 	lemma: o
# word: fumaca 	lemma: fumaca
# word: proveniente 	lemma: proveniente
# word: da 	lemma: da
# word: combustao 	lemma: combustao
# word: da 	lemma: da
# word: lenha 	lemma: lenha
# word: no 	lemma: ele
# word: domicilio 	lemma: domicilio
# word: e 	lemma: e
# word: exposicao 	lemma: exposicao
# word: ao 	lemma: ao
# word: radonio 	lemma: radonio
